# %% [markdown]
# # Домашнє завдання до теми "Functions"

# %% [markdown]
# 1. Напишіть фукнцію `print_message`, яка виводить на екран "Я програмую на Python💪" і викличіть цю фукнцію 5 разів (найкраще це зробити в циклі).
#
#   **Увага**: фукнція має робити чітко лише зазначений функціонал. Наявність додаткового функціоналу і аргументів, які не потрібні для виконання безпосередньо завдання, буде вважатись помилкою.

# %%
# Solution 1. The function outputs text by using "for" loop:
def print_message():
  for i in range (5):
    print("Я програмую на Python💪")

print_message()
# Out:
# Я програмую на Python💪
# Я програмую на Python💪
# Я програмую на Python💪
# Я програмую на Python💪
# Я програмую на Python💪

# %%
# Solution 2. The function "print_message" outputs text by using "while" loop:

def print_message():
  i = 1
  while i <= 5:
    print("Я програмую на Python💪")
    i += 1

print_message()
# Out:
# Я програмую на Python💪
# Я програмую на Python💪
# Я програмую на Python💪
# Я програмую на Python💪
# Я програмую на Python💪

# %% [markdown]
# 2. Напишіть функцію `calculation` яка приймає на вхід 4 аргументи типу int - `a`, `b`, `c`, `d` і вертає результат обчислення такої формули: $ (a + b - c) * d $.
#
#   Викличте функцію на наступному наборі аргументів і виведіть результат на екран:
#   ```
#   a = 16
#   b = 4
#   c = 9
#   d = 3
#   ```

# %%
# Solution 1.

def calculation():
  a = 16
  b = 4
  c = 9
  d = 3
  print((a + b - c) * d)

calculation()
# Out:
# 33

# %%
# Solution 2.

## Можна дописати ще ДОКСТРІНГ!!!!

def calculation(a, b, c, d):
  """

  """

  type(a) == int, type(b) == int, type(c) == int, type(d) == int
  return (a + b - c) * d

calculation(16, 4, 9, 3)
# Out:
# 33

# %%
# Checking correctness of function by direct math calculation according to given formula:

(16 + 4 - 9) * 3
# Out:
# 33

# %% [markdown]
# 3. Напишіть функцію, яка додає до аргумента 15 і вертає результат додавання. Викличте функцію, передаючи в якості аргументів кожну з наступних змінних по черзі, і виведіть кожного разу результат на екран.
# ```
# x = 9
# y = 14
# z = -19
# ```

# %%
def add_fifteen(x):
  """
    Adds 15 to the given number and returns the result.
    
    :param number: The number to add 15 to
    :type number: int or float
    :returns: The sum of the input number and 15
    :rtype: int or float
    """
  return x + 15

x = 9
y = 14
z = -19

print(add_fifteen(x))
print(add_fifteen(y))
print(add_fifteen(z))
# Out:
# 24
# 29
# -4

# %% [markdown]
# 4. Напишіть функцію `multipy_numbers`, яка приймає два числа як аргументи і повертає їх добуток.
#
#   Викличіть функцію `multipy_numbers` на парах чисел
# - 10 і 2
# - 7 і 8
# - 1024 і 999.
#
#   Виведіть результат кожного виклику.
#   При виконанні цього завдання з використанням циклу - отримаєте 2х балів за нього :)

# %%
# Solution 1.  
 
def multiply_numbers(x, y):
  return x * y

display((multiply_numbers(10, 2)), multiply_numbers(7, 8), multiply_numbers(1024, 999))
# Out:
# 20
# 56
# 1022976

# %%
# Solution 2. Function with doc string

def multiply_numbers(num1, num2):
   """
   Multiplies two numbers and returns their product.
   
   :param num1: First number to multiply
   :type num1: int or float
   :param num2: Second number to multiply 
   :type num2: int or float
   :returns: Product of the two input numbers
   :rtype: int or float
   """
   return num1 * num2

# Call function with each pair and print results

print(multiply_numbers(10, 2))
print(multiply_numbers(7, 8))
print(multiply_numbers(1024, 999))
# Out:
# 20
# 56
# 1022976

# %%
# Solution 3. Create function and "for" loop

def multiply_numbers(num1, num2):
   """
   Multiplies two numbers and returns their product.
   
   :param num1: First number to multiply
   :type num1: int or float
   :param num2: Second number to multiply
   :type num2: int or float
   :returns: Product of the two input numbers
   :rtype: int or float
   """
   return num1 * num2

# List of number pairs to multiply

number_pairs = [
   (10, 2),
   (7, 8),
   (1024, 999)
]

# Loop through pairs and print results

for num1, num2 in number_pairs:
   result = multiply_numbers(num1, num2)
   print(f"{num1} * {num2} = {result}")
# Out:
# 10 * 2 = 20
# 7 * 8 = 56
# 1024 * 999 = 1022976

# %% [markdown]
# 5. **Ділення з перевіркою типів.**
#
#   1. Напишіть функцію `int_division` яка приймає на вхід два аргументи типу `int` - `a` і `b`, і виконує ділення першого аргумента на другий: `a/b`. При цьому функція перед діленням перевіряє, чи другий аргумент не дорівнює 0. Якщо другий аргумент не 0, фукнція вертає результат ділення, інакше - замість виконання ділення, вертає повідомлення на екран "Не можу виконати ділення на 0".
#
#     Якщо типи, надані у функцію, не `int` - функція виводить повідомлення "Не працюю з такими типами даних.".
#
#   2. Запустіть функцію на наступних парах чисел:
# - 12 і 6
# - 20 і 0
# - 112 і 10
# - 99 і 0
# - 11 i 1.1
#
#     і виведіть на екран повідомлення "Результат роботи функції: " - і далі те, що повернула функція.
#
#   3. Дайте відповідь на питання: "Чому в деяких випадках функція повернула None?"

# %% [markdown]
# ##### Відповідь на питання 3:
#
# ###### 1.Коли b дорівнює 0, функція лише виводить повідомлення, але не повертає жодного значення. У Python функція за замовчуванням повертає None (коли не вказано значення, що повертається).
# ###### 2. Якщо перша умова type(a) == int і type(b) == int має значення False (як у випадку з int_division(11, 1.1)). Функція не виконує ніякого коду і неявно повертає None.
# ###### 3. None з'являється тоді, коли не вказано оператор return у функції.

# %%
# Solution 2. 

def int_division(a, b):

    # Check if both arguments are integers
    if not isinstance(a, int) or not isinstance(b, int):
        return "Не працюю з такими типами даних."

    # Check if the second argument is zero

    if b == 0:
        return "Не можу виконати ділення на 0."

    # Perform division

    return a / b

# Write test cases

test_pairs = [
    (12, 6),
    (20, 0),
    (112, 10),
    (99, 0),
    (11, 1.1)
]

# Execute the function on each pair and print the results (by using for loop)

for a, b in test_pairs:
    result = int_division(a, b)
    print(f"Function result: {result}")
# Out:
# Function result: 2.0
# Function result: Не можу виконати ділення на 0.
# Function result: 11.2
# Function result: Не можу виконати ділення на 0.
# Function result: Не працюю з такими типами даних.

# %%
# Solution 3.

def int_division(a, b):
    # Check if both arguments are integers
    if not isinstance(a, int) or not isinstance(b, int):
        return "Не працюю з такими типами даних."

    # Check if the second argument is zero
    if b == 0:
        return "Не можу виконати ділення на 0."

    # Perform division
    return a / b

# Test cases and outputs
print(f"Function result: {int_division(12, 6)}.")
print(f"Function result: {int_division(20, 0)}.")
print(f"Function result: {int_division(112, 10)}.")
print(f"Function result: {int_division(99, 0)}.")
print(f"Function result: {int_division(11, 1.1)}.")
# Out:
# Function result: 2.0.
# Function result: Не можу виконати ділення на 0..
# Function result: 11.2.
# Function result: Не можу виконати ділення на 0..
# Function result: Не працюю з такими типами даних..
